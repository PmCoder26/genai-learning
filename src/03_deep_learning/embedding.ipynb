# %% [markdown]
# # Word Embeddings
#
# An embedding is a dense numerical representation of a word. Instead of a very large sparse one-hot vector, each word is mapped to a smaller vector whose values are learned from context. Words with similar meanings tend to have similar embedding vectors.
#
# This notebook demonstrates the basic idea using a small text dataset and a Keras Embedding layer. The goal is to understand how a word index is converted into a learned dense vector representation.

# %%
# One-hot encoding is a simple way to represent words numerically.
# Each word gets a unique index in the vocabulary, and a long vector is created

# where only one position is 1 and all others are 0.from tensorflow.keras.preprocessing.text import one_hot

# This is useful for understanding the idea, but it is not efficient for NLP models,# because words are represented as very large sparse vectors.

# %%
# These example sentences are a small text corpus for demonstration purposes.
# The goal is to show how text can be converted into numeric form before passing
# it into a neural network. Even in a tiny example, we can see repeated terms and
# similar sentence structures that learning-based representations can capture.
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',

    'understand the meaning of words',]
    'your videos are good'

# %%
# The vocabulary size is the total number of unique words the model can represent.
# A large value like 10000 makes sure that the sample text fits comfortably

# inside the vocabulary, even if the dataset grows later.vocab_size = 10000

# %%
# Each sentence is turned into a list of one-hot encodings for its words.
# This creates a numeric representation that a model can accept, although it is
# still high-dimensional and sparse compared with learned embeddings.

one_hot_repr = [one_hot(words, vocab_size) for words in sent]one_hot_repr
# Out:
# [[6100, 4881, 8052, 9359],
#  [6100, 4881, 8052, 9606],
#  [6100, 1474, 8052, 735],
#  [4484, 3141, 8502, 567, 4344],
#  [4484, 3141, 8502, 567, 9207],
#  [7449, 6100, 8707, 8052, 7430],
#  [6301, 7246, 6293, 567]]

# %%
# An embedding layer is a learnable lookup table.
# Instead of using huge one-hot representations, every word index is mapped to a
# compact dense vector of fixed size. These vectors are learned during training, and
# similar words tend to end up close together in embedding space.
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequentialimport numpy as np

# %%
# Neural networks usually expect all input sequences to have the same length.
# Padding adds zero values at the start of shorter sequences so the data can be
# stacked into a consistent matrix. Here, each sentence is padded to a length of 10.
sent_len = 10

embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_len)embedded_docs
# Out:
# array([[   0,    0,    0,    0,    0,    0, 6100, 4881, 8052, 9359],
#        [   0,    0,    0,    0,    0,    0, 6100, 4881, 8052, 9606],
#        [   0,    0,    0,    0,    0,    0, 6100, 1474, 8052,  735],
#        [   0,    0,    0,    0,    0, 4484, 3141, 8502,  567, 4344],
#        [   0,    0,    0,    0,    0, 4484, 3141, 8502,  567, 9207],
#        [   0,    0,    0,    0,    0, 7449, 6100, 8707, 8052, 7430],
#        [   0,    0,    0,    0,    0,    0, 6301, 7246, 6293,  567]],
#       dtype=int32)

# %%
# The embedding dimension controls how large each learned word vector is.
# A dimension of 10 means each word is represented by a 10-value vector, rather

# than by a huge one-hot vector. This is a very small example, but it shows the idea.dimension = 10

# %%
# We create a very small neural network that contains only an Embedding layer.
# The layer receives integer word indices and converts each one to a dense vector.
# Keras handles the mapping automatically, and the model can be trained later.
model = Sequential()

model.add(Embedding(vocab_size, dimension, input_length=sent_len))

model.compile('adam', 'mse')
# Out:
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:123: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# model.summary() shows the architecture and parameter counts.
# This helps us understand how the embedding layer maps the vocabulary into a

# smaller vector space. In a larger model, this layer would learn meaningfulmodel.summary()
# semantic patterns from the data during training.
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# The model generates dense vectors for each word position in the input sequences.
# These learned vectors are the actual embedding output. In a real application,

# these vectors are usually used as input features for downstream tasks such asmodel.predict(embedded_docs)
# classification, sentiment analysis, or retrieval.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# array([[[ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.03253055,  0.0092175 ,  0.04678955, -0.03366113,
#          -0.02155296, -0.01100128, -0.0077429 , -0.0374403 ,
#           0.01392097,  0.03179865],
#         [ 0.0423171 , -0.04319007,  0.04370124,  0.0296298 ,
#          -0.01355166, -0.00548798,  0.01339428, -0.04891386,
#          -0.04503726,  0.0343207 ],
#         [-0.02008255,  0.02599956,  0.04707393,  0.0474571 ,
#           0.03748399,  0.02060838, -0.01731605,  0.01795455,
#           0.02559317, -0.04690399],
#         [-0.00562636, -0.00269219,  0.02838236,  0.00651729,
#           0.04660435,  0.04129807, -0.03847231,  0.02314364,
#           0.00873418,  0.03038112]],
#
#        [[ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.03253055,  0.0092175 ,  0.04678955, -0.03366113,
#          -0.02155296, -0.01100128, -0.0077429 , -0.0374403 ,
#           0.01392097,  0.03179865],
#         [ 0.0423171 , -0.04319007,  0.04370124,  0.0296298 ,
#          -0.01355166, -0.00548798,  0.01339428, -0.04891386,
#          -0.04503726,  0.0343207 ],
#         [-0.02008255,  0.02599956,  0.04707393,  0.0474571 ,
#           0.03748399,  0.02060838, -0.01731605,  0.01795455,
#           0.02559317, -0.04690399],
#         [ 0.02484577,  0.01552231,  0.03546604, -0.02606573,
#          -0.00789731,  0.01615128,  0.01094981,  0.02309782,
#           0.04961792, -0.04560927]],
#
#        [[ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.03253055,  0.0092175 ,  0.04678955, -0.03366113,
#          -0.02155296, -0.01100128, -0.0077429 , -0.0374403 ,
#           0.01392097,  0.03179865],
#         [ 0.01770407,  0.04507789,  0.02097261, -0.03449359,
#          -0.04729016,  0.03607321, -0.04533862,  0.00764351,
#          -0.02057021, -0.03711883],
#         [-0.02008255,  0.02599956,  0.04707393,  0.0474571 ,
#           0.03748399,  0.02060838, -0.01731605,  0.01795455,
#           0.02559317, -0.04690399],
#         [-0.02449657, -0.01473721,  0.01719207,  0.03112063,
#           0.04506664,  0.01289629,  0.03682561,  0.04161019,
#          -0.03621139,  0.00652147]],
#
#        [[ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.00019205, -0.00572541,  0.03054768, -0.03236222,
#           0.02788739, -0.02597898, -0.04868261,  0.03041326,
#           0.03761106,  0.015511  ],
#         [-0.02513549,  0.04563263,  0.0211168 ,  0.01348648,
#           0.00250176,  0.02255603, -0.04185534, -0.00353943,
#           0.0006416 , -0.00412482],
#         [-0.03352275,  0.04789681,  0.01609062, -0.03856637,
#           0.0453265 ,  0.01100097, -0.03637185, -0.02438917,
#          -0.02624403, -0.04609926],
#         [ 0.04469294,  0.03633088, -0.01279421, -0.00771748,
#           0.03839034, -0.02725923, -0.03864471, -0.03710395,
#          -0.01205897,  0.03468481],
#         [ 0.02372679, -0.01015885, -0.04755709, -0.03242054,
#           0.01278101,  0.02523888,  0.01748406,  0.01787776,
#          -0.00581288, -0.01780494]],
#
#        [[ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.00019205, -0.00572541,  0.03054768, -0.03236222,
#           0.02788739, -0.02597898, -0.04868261,  0.03041326,
#           0.03761106,  0.015511  ],
#         [-0.02513549,  0.04563263,  0.0211168 ,  0.01348648,
#           0.00250176,  0.02255603, -0.04185534, -0.00353943,
#           0.0006416 , -0.00412482],
#         [-0.03352275,  0.04789681,  0.01609062, -0.03856637,
#           0.0453265 ,  0.01100097, -0.03637185, -0.02438917,
#          -0.02624403, -0.04609926],
#         [ 0.04469294,  0.03633088, -0.01279421, -0.00771748,
#           0.03839034, -0.02725923, -0.03864471, -0.03710395,
#          -0.01205897,  0.03468481],
#         [ 0.03427837,  0.006209  ,  0.03089572,  0.01261291,
#           0.01897173, -0.04568485, -0.02871509,  0.02962262,
#          -0.01966901, -0.0020769 ]],
#
#        [[ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [-0.00386857, -0.03392756, -0.01383642,  0.01914835,
#          -0.04302711, -0.04564822, -0.04461847, -0.0085266 ,
#          -0.03027675,  0.02236329],
#         [ 0.03253055,  0.0092175 ,  0.04678955, -0.03366113,
#          -0.02155296, -0.01100128, -0.0077429 , -0.0374403 ,
#           0.01392097,  0.03179865],
#         [ 0.04564032, -0.0349722 , -0.00961868,  0.04738757,
#           0.02822726, -0.02263804, -0.00234861, -0.04107725,
#           0.01247229,  0.03973286],
#         [-0.02008255,  0.02599956,  0.04707393,  0.0474571 ,
#           0.03748399,  0.02060838, -0.01731605,  0.01795455,
#           0.02559317, -0.04690399],
#         [-0.02438124, -0.00278271,  0.00179197,  0.00950585,
#          -0.03980553,  0.04601565, -0.040712  , -0.02049426,
#          -0.01929598,  0.01832305]],
#
#        [[ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [ 0.0273039 , -0.04973642,  0.01514927, -0.04012068,
#           0.01149591, -0.01908933,  0.01437962,  0.02695647,
#           0.00552925,  0.02537668],
#         [-0.04647355,  0.01948241, -0.03969054,  0.03602692,
#          -0.00133785,  0.04887006,  0.03160186,  0.02987745,
#          -0.02428029,  0.03990329],
#         [ 0.02328191, -0.04526014, -0.02811245, -0.04164786,
#          -0.03745143,  0.00681504,  0.0467138 ,  0.02432487,
#           0.0181469 , -0.01041696],
#         [ 0.02004716,  0.01885475, -0.04258681, -0.00583053,
#          -0.0426055 , -0.01618377, -0.01261487, -0.00804851,
#           0.02950329,  0.0283146 ],
#         [ 0.04469294,  0.03633088, -0.01279421, -0.00771748,
#           0.03839034, -0.02725923, -0.03864471, -0.03710395,
#          -0.01205897,  0.03468481]]], dtype=float32)

# %%
# This example is intentionally small to make the concept easy to understand. In real NLP
# projects, embeddings are trained on large corpora and capture richer relationships

# between words, phrases, and contexts. The core idea is the same: transform discrete
# tokens into dense vectors that encode meaning in a machine-readable form.
